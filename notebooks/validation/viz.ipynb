# %%
results = {
    'mas': {
        'inverse_stats': "/Users/sefika/phd_projects/llm-catastrophic-re/results_all/fewrel_corrected_results/tmlr/mas/canonical_errors/inverse_stats_mas.json",
        'incorrect_stats': "/Users/sefika/phd_projects/llm-catastrophic-re/results_all/fewrel_corrected_results/tmlr/mas/canonical_errors/incorrect_stats_mas.json",
        'canonical_stats': "/Users/sefika/phd_projects/llm-catastrophic-re/results_all/fewrel_corrected_results/tmlr/mas/canonical_errors/canonical_stats_mas.json",
        'hallucination_stats': "/Users/sefika/phd_projects/llm-catastrophic-re/results_all/fewrel_corrected_results/tmlr/mas/canonical_errors/hallucination_stats_mas.json"
    },
    'baseline': {
        'inverse_stats': "/Users/sefika/phd_projects/llm-catastrophic-re/results_all/fewrel_corrected_results/tmlr/baseline/canonical_errors/inverse_stats_baseline.json",
        'incorrect_stats': "/Users/sefika/phd_projects/llm-catastrophic-re/results_all/fewrel_corrected_results/tmlr/baseline/canonical_errors/incorrect_stats_baseline.json",
        'canonical_stats': "/Users/sefika/phd_projects/llm-catastrophic-re/results_all/fewrel_corrected_results/tmlr/baseline/canonical_errors/canonical_stats_baseline.json",
        'hallucination_stats': "/Users/sefika/phd_projects/llm-catastrophic-re/results_all/fewrel_corrected_results/tmlr/baseline/canonical_errors/hallucination_stats_baseline.json"
    },
    'ewc': {
        'inverse_stats': "/Users/sefika/phd_projects/llm-catastrophic-re/results_all/fewrel_corrected_results/tmlr/ewc/canonical_errors/inverse_stats_ewc.json",
        'incorrect_stats': "/Users/sefika/phd_projects/llm-catastrophic-re/results_all/fewrel_corrected_results/tmlr/ewc/canonical_errors/incorrect_stats_ewc.json",
        'canonical_stats': "/Users/sefika/phd_projects/llm-catastrophic-re/results_all/fewrel_corrected_results/tmlr/ewc/canonical_errors/canonical_stats_ewc.json",
        'hallucination_stats': "/Users/sefika/phd_projects/llm-catastrophic-re/results_all/fewrel_corrected_results/tmlr/ewc/canonical_errors/hallucination_stats_ewc.json"
    },
    'si': {
        'inverse_stats': "/Users/sefika/phd_projects/llm-catastrophic-re/results_all/fewrel_corrected_results/tmlr/si/canonical_errors/inverse_stats_si.json",
        'incorrect_stats': "/Users/sefika/phd_projects/llm-catastrophic-re/results_all/fewrel_corrected_results/tmlr/si/canonical_errors/incorrect_stats_si.json",
        'canonical_stats': "/Users/sefika/phd_projects/llm-catastrophic-re/results_all/fewrel_corrected_results/tmlr/si/canonical_errors/canonical_stats_si.json",
        'hallucination_stats': "/Users/sefika/phd_projects/llm-catastrophic-re/results_all/fewrel_corrected_results/tmlr/si/canonical_errors/hallucination_stats_si.json"
    }
}

# %%
import pandas as pd

# %%
# baseline
df_pred_incorrect = pd.json_normalize(pd.read_json(results['baseline']['incorrect_stats']).to_dict(orient="records"))
df_pred_inverse = pd.json_normalize(pd.read_json(results['baseline']['inverse_stats']).to_dict(orient="records"))
df_pred_canonical = pd.json_normalize(pd.read_json(results['baseline']['canonical_stats']).to_dict(orient="records"))
df_pred_hallucination = pd.json_normalize(pd.read_json(results['baseline']['hallucination_stats']).to_dict(orient="records"))

# %%
baseline_incorrect = list(df_pred_incorrect['total_incorrect_no_suggestion'])
baseline_inverse = list(df_pred_inverse['total_inverse_matches'])
baseline_no_inverse = list(df_pred_inverse['total_no_matches'])
baseline_canonical = list(df_pred_canonical['total_canonical_matches'])
baseline_no_canonical = list(df_pred_canonical['total_no_matches'])
baseline_hallucination = list(df_pred_hallucination['total_hallucination'])

# %%
# baseline
ewc_df_pred_incorrect = pd.json_normalize(pd.read_json(results['ewc']['incorrect_stats']).to_dict(orient="records"))
ewc_df_pred_inverse = pd.json_normalize(pd.read_json(results['ewc']['inverse_stats']).to_dict(orient="records"))
ewc_df_pred_canonical = pd.json_normalize(pd.read_json(results['ewc']['canonical_stats']).to_dict(orient="records"))  
ewc_df_pred_hallucination = pd.json_normalize(pd.read_json(results['ewc']['hallucination_stats']).to_dict(orient="records"))

ewc_incorrect = list(ewc_df_pred_incorrect['total_incorrect_no_suggestion'])
ewc_inverse = list(ewc_df_pred_inverse['total_inverse_matches'])
ewc_no_inverse = list(ewc_df_pred_inverse['total_no_matches'])
ewc_canonical = list(ewc_df_pred_canonical['total_canonical_matches'])
ewc_no_canonical = list(ewc_df_pred_canonical['total_no_matches'])
ewc_hallucination = list(ewc_df_pred_hallucination['total_hallucination'])

# %%
# baseline
si_df_pred_incorrect = pd.json_normalize(pd.read_json(results['si']['incorrect_stats']).to_dict(orient="records"))
si_df_pred_inverse = pd.json_normalize(pd.read_json(results['si']['inverse_stats']).to_dict(orient="records"))
si_df_pred_canonical = pd.json_normalize(pd.read_json(results['si']['canonical_stats']).to_dict(orient="records"))  
si_incorrect = list(si_df_pred_incorrect['total_incorrect_no_suggestion'])
si_inverse = list(si_df_pred_inverse['total_inverse_matches'])
si_no_inverse = list(si_df_pred_inverse['total_no_matches'])
si_canonical = list(si_df_pred_canonical['total_canonical_matches'])
si_no_canonical = list(si_df_pred_canonical['total_no_matches'])
si_df_pred_hallucination = pd.json_normalize(pd.read_json(results['si']['hallucination_stats']).to_dict(orient="records"))
si_hallucination = list(si_df_pred_hallucination['total_hallucination'])

# %%
# baseline
mas_df_pred_incorrect = pd.json_normalize(pd.read_json(results['mas']['incorrect_stats']).to_dict(orient="records"))
mas_df_pred_inverse = pd.json_normalize(pd.read_json(results['mas']['inverse_stats']).to_dict(orient="records"))
mas_df_pred_canonical = pd.json_normalize(pd.read_json(results['mas']['canonical_stats']).to_dict(orient="records"))  
mas_incorrect = list(mas_df_pred_incorrect['total_incorrect_no_suggestion'])
mas_inverse = list(mas_df_pred_inverse['total_inverse_matches'])
mas_no_inverse = list(mas_df_pred_inverse['total_no_matches'])
mas_canonical = list(mas_df_pred_canonical['total_canonical_matches'])
mas_no_canonical = list(mas_df_pred_canonical['total_no_matches'])
mas_df_pred_hallucination = pd.json_normalize(pd.read_json(results['mas']['hallucination_stats']).to_dict(orient="records"))
mas_hallucination = list(mas_df_pred_hallucination['total_hallucination'])

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

for MODEL_NAME in ["Baseline", "EWC", "SI", "MAS"]:

    # =======================
    # LOAD DATA PER MODEL
    # =======================
    if MODEL_NAME == "Baseline":
        incorrect = list(df_pred_incorrect['total_incorrect_no_suggestion'])
        incorrect = [ a+b for a, b in zip(incorrect, baseline_no_inverse)]
        inverse   = list(df_pred_inverse['total_inverse_matches'])
        canonical = list(df_pred_canonical['total_canonical_matches'])
        halluc    = list(df_pred_hallucination['total_hallucination'])
        no_canonical = baseline_no_canonical  

    elif MODEL_NAME == "EWC":
        incorrect = list(ewc_df_pred_incorrect['total_incorrect_no_suggestion'])
        incorrect = [ a+b for a, b in zip(incorrect, ewc_no_inverse)]
        inverse   = list(ewc_df_pred_inverse['total_inverse_matches'])
        canonical = list(ewc_df_pred_canonical['total_canonical_matches'])
        halluc    = list(ewc_df_pred_hallucination['total_hallucination'])
        no_canonical = ewc_no_canonical

    elif MODEL_NAME == "SI":
        incorrect = list(si_df_pred_incorrect['total_incorrect_no_suggestion'])
        incorrect = [ a+b for a, b in zip(incorrect, si_no_inverse)]
        inverse   = list(si_df_pred_inverse['total_inverse_matches'])
        canonical = list(si_df_pred_canonical['total_canonical_matches'])
        halluc    = list(si_df_pred_hallucination['total_hallucination'])
        no_canonical = si_no_canonical

    elif MODEL_NAME == "MAS":
        incorrect = list(mas_df_pred_incorrect['total_incorrect_no_suggestion'])
        incorrect = [ a+b for a, b in zip(incorrect, mas_no_inverse)]
        inverse   = list(mas_df_pred_inverse['total_inverse_matches'])
        canonical = list(mas_df_pred_canonical['total_canonical_matches'])
        halluc    = list(mas_df_pred_hallucination['total_hallucination'])
        no_canonical = mas_no_canonical

    else:
        raise ValueError("Unknown MODEL_NAME")

    # =======================
    # SANITY CHECK
    # =======================
    assert len(incorrect) == len(inverse) == len(canonical) == len(halluc)

    # =======================
    # BUILD DATAFRAME
    # =======================
    index_labels = [
        "Incorrect",
        "Canonical (Incorrect)",
        "Hallucination",
        "Inverse (Correct)",
        "Canonical (Correct)"
    ]

    df = pd.DataFrame(
        [incorrect, no_canonical, halluc, inverse, canonical],
        index=index_labels
    )

    # =======================
    # PLOT
    # =======================
    plt.figure(figsize=(10, 4))

    sns.heatmap(
        df,
        annot=True,
        fmt=".0f",
        cmap="Blues",
        annot_kws={
            "size": 14,        # 🔹 increase cell font size
            "weight": "bold"  # 🔹 make cell numbers bold
        }
    )

    plt.title(f"{MODEL_NAME}: Error Types across Tasks", fontsize=16, weight="bold")
    plt.xlabel("Task Index", fontsize=14, weight="bold")
    plt.ylabel("Error Type", fontsize=14, weight="bold")

    plt.xticks(fontsize=12, weight="bold")
    plt.yticks(fontsize=12, weight="bold", rotation=0)

    plt.tight_layout()
    plt.savefig(f"{MODEL_NAME.lower()}_errors_comparison.pdf", dpi=300)
    plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# ---------- BASELINE ----------
baseline_incorrect = list(df_pred_incorrect['total_incorrect_no_suggestion'])

baseline_inverse_match = list(df_pred_inverse['total_inverse_matches'])
baseline_canonical_match = list(df_pred_canonical['total_canonical_matches'])

# ---------- EWC ----------
ewc_incorrect = list(ewc_df_pred_incorrect['total_incorrect_no_suggestion'])
ewc_inverse_match = list(ewc_df_pred_inverse['total_inverse_matches'])
ewc_canonical_match = list(ewc_df_pred_canonical['total_canonical_matches'])

# ---------- SI ----------
si_incorrect = list(si_df_pred_incorrect['total_incorrect_no_suggestion'])
si_inverse_match = list(si_df_pred_inverse['total_inverse_matches'])
si_canonical_match = list(si_df_pred_canonical['total_canonical_matches'])

# ---------- MAS ----------
mas_incorrect = list(mas_df_pred_incorrect['total_incorrect_no_suggestion'])
mas_inverse_match = list(mas_df_pred_inverse['total_inverse_matches'])
mas_canonical_match = list(mas_df_pred_canonical['total_canonical_matches'])

# ---------- Sanity checks ----------
assert len(baseline_incorrect) == len(ewc_incorrect) == len(si_incorrect) == len(mas_incorrect)
assert len(baseline_inverse_match) == len(ewc_inverse_match) == len(si_inverse_match) == len(mas_inverse_match)
assert len(baseline_canonical_match) == len(ewc_canonical_match) == len(si_canonical_match) == len(mas_canonical_match)

# ---------- DataFrames ----------
index_labels = [
    'Incorrect (No Suggestion)',
    'Inverse (Match)',
    'Canonical (Match)'
]

def make_df(incorrect, inv_m, can_m):
    return pd.DataFrame([incorrect, inv_m, can_m], index=index_labels)

baseline_df = make_df(baseline_incorrect, baseline_inverse_match, baseline_canonical_match)
ewc_df = make_df(ewc_incorrect, ewc_inverse_match, ewc_canonical_match)
si_df = make_df(si_incorrect, si_inverse_match, si_canonical_match)
mas_df = make_df(mas_incorrect, mas_inverse_match, mas_canonical_match)

# ---------- Plot ----------
fig, axes = plt.subplots(4, 1, figsize=(12, 12), sharex=True)

for ax, df, title in zip(
    axes,
    [baseline_df, ewc_df, si_df, mas_df],
    ['Baseline', 'EWC', 'SI', 'MAS']
):
    sns.heatmap(df, annot=True, fmt=".0f", cmap="Blues", ax=ax)
    ax.set_title(f'{title}: Incorrect vs Match Counts')
    ax.set_ylabel('')

axes[-1].set_xlabel('Task / Relation Index')

plt.tight_layout()
plt.show()

# %%
# baseline
df_pred_incorrect = pd.json_normalize(pd.read_json(results['mas']['incorrect_stats']).to_dict(orient="records"))
df_pred_inverse = pd.json_normalize(pd.read_json(results['mas']['inverse_stats']).to_dict(orient="records"))
df_pred_canonical = pd.json_normalize(pd.read_json(results['mas']['canonical_stats']).to_dict(orient="records"))

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


incorrect = list(df_pred_incorrect['total_incorrect_no_suggestion'])
inverse = list(df_pred_inverse['total_inverse_matches'])
no_inverse = list(df_pred_inverse['total_no_matches'])
canonical = list(df_pred_canonical['total_canonical_matches'])
no_canonical = list(df_pred_canonical['total_no_matches'])

heatmap_df = pd.DataFrame(
    [incorrect, inverse, no_inverse, canonical, no_canonical],
    index=['Incorrect', 'Inverse Match', 'No Match Inverse', 'Canonical Match', 'No Match Canonical']
)

plt.figure(figsize=(12, 4))
sns.heatmap(
    heatmap_df,
    annot=True,
    fmt=".0f",
    cmap="Blues"
)

plt.xlabel('Task Index')
plt.ylabel('Error Type')
plt.title('Error Counts and Types Heatmap')
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import rcParams

# -----------------------
# ACL-ish matplotlib style
# -----------------------
rcParams.update({
    "font.family": "serif",
    "font.size": 9,
    "axes.titlesize": 9,
    "axes.labelsize": 9,
    "xtick.labelsize": 8,
    "ytick.labelsize": 8,
    "axes.linewidth": 0.8,
    "pdf.fonttype": 42,
    "ps.fonttype": 42,
})

# -----------------------
# Labels + colors
# -----------------------
index_labels = [
    "Incorrect",
    "Canonical (Incorrect)",
    "Hallucination",
    "Inverse (Correct)",
    "Canonical (Correct)"
]

colors = {
    "Incorrect": "#D50000",
    "Canonical (Incorrect)": "#4D00E6",
    "Hallucination": "#73AEAD",
    "Inverse (Correct)": "#8FE551",
    "Canonical (Correct)": "#000000"
}

# -----------------------
# MAIN: horizontal stacked bars (ACL-style)
# -----------------------
for MODEL_NAME in ["Baseline", "EWC", "SI", "MAS"]:

    # =======================
    # LOAD DATA PER MODEL
    # =======================
    if MODEL_NAME == "Baseline":
        incorrect = list(df_pred_incorrect["total_incorrect_no_suggestion"])
        incorrect = [a + b for a, b in zip(incorrect, baseline_no_inverse)]
        inverse   = list(df_pred_inverse["total_inverse_matches"])
        canonical = list(df_pred_canonical["total_canonical_matches"])
        halluc    = list(df_pred_hallucination["total_hallucination"])
        no_canonical = baseline_no_canonical

    elif MODEL_NAME == "EWC":
        incorrect = list(ewc_df_pred_incorrect["total_incorrect_no_suggestion"])
        incorrect = [a + b for a, b in zip(incorrect, ewc_no_inverse)]
        inverse   = list(ewc_df_pred_inverse["total_inverse_matches"])
        canonical = list(ewc_df_pred_canonical["total_canonical_matches"])
        halluc    = list(ewc_df_pred_hallucination["total_hallucination"])
        no_canonical = ewc_no_canonical

    elif MODEL_NAME == "SI":
        incorrect = list(si_df_pred_incorrect["total_incorrect_no_suggestion"])
        incorrect = [a + b for a, b in zip(incorrect, si_no_inverse)]
        inverse   = list(si_df_pred_inverse["total_inverse_matches"])
        canonical = list(si_df_pred_canonical["total_canonical_matches"])
        halluc    = list(si_df_pred_hallucination["total_hallucination"])
        no_canonical = si_no_canonical

    elif MODEL_NAME == "MAS":
        incorrect = list(mas_df_pred_incorrect["total_incorrect_no_suggestion"])
        incorrect = [a + b for a, b in zip(incorrect, mas_no_inverse)]
        inverse   = list(mas_df_pred_inverse["total_inverse_matches"])
        canonical = list(mas_df_pred_canonical["total_canonical_matches"])
        halluc    = list(mas_df_pred_hallucination["total_hallucination"])
        no_canonical = mas_no_canonical

    else:
        raise ValueError("Unknown MODEL_NAME")

    assert len(incorrect) == len(inverse) == len(canonical) == len(halluc) == len(no_canonical)

    # =======================
    # BUILD DATAFRAME
    # =======================
    df = pd.DataFrame(
        [incorrect, no_canonical, halluc, inverse, canonical],
        index=index_labels
    )

    # =======================
    # PLOT: HORIZONTAL STACKED
    # =======================
    n_tasks = df.shape[1]
    y = np.arange(1, n_tasks + 1)

    fig, ax = plt.subplots(figsize=(6.2, 3.2))

    left_true = np.zeros(n_tasks)
    left_disp = np.zeros(n_tasks)
    eps = 0.5

    for lab in index_labels:
        vals = df.loc[lab].values.astype(float)
        display_vals = np.where(vals > 0, np.maximum(vals, eps), 0)

        ax.barh(
            y,
            display_vals,
            left=left_disp,
            color=colors[lab],
            label=lab,
            height=0.75
        )

        left_true += vals
        left_disp += display_vals

    # ---- Totals at end of stacks
    max_total = float(np.max(left_true)) if n_tasks > 0 else 0.0
    x_pad = max(1.0, 0.025 * max_total)

    for yi, total in zip(y, left_true):
        ax.text(
            total + x_pad,
            yi,
            f"{int(round(total))}",
            va="center",
            ha="left",
            fontsize=8
        )

    ax.set_xlim(0, max_total + 8 * x_pad)

    ax.set_ylabel("Task Index", fontsize=12, weight="bold")
    ax.set_xlabel("Count", fontsize=12, weight="bold")
    ax.set_title(f"Errors Per Task", fontsize=10, weight="bold")

    ax.set_yticks(y)
    ax.invert_yaxis()

    # =======================
    # LEGEND AT TOP (FIXED)
    # =======================
    ax.legend(
        frameon=False,
        loc="lower center",
        bbox_to_anchor=(0.5, 1.06),
        ncol=3  # forces two rows (3 + 2)
    )

    # Adjust layout so legend fits nicely
    fig.tight_layout(pad=0.3)
    plt.subplots_adjust(top=0.82)

    plt.savefig(f"fewrel_stacked/{MODEL_NAME.lower()}_errors.pdf")
    plt.show()

# %%
### ----------------------- LLM as a Judge with NLI

import numpy as np
import matplotlib.pyplot as plt
from matplotlib import rcParams
import os

# -----------------------
# Style (paper-friendly, big figure)
# -----------------------
rcParams.update({
    "font.family": "serif",
    "font.size": 16,
    "axes.titlesize": 16,
    "axes.labelsize": 14,
    "xtick.labelsize": 14,
    "ytick.labelsize": 14,
    "axes.linewidth": 0.8,
})

# -----------------------
# Data
# -----------------------
runs = np.arange(1, 6)
x = np.arange(len(runs))
bar_w = 0.48

data = {
    "TACRED": {
        "model_false": np.array([159, 349, 253, 421, 217]),
        "correct_judged": np.array([149, 333, 237, 359, 198]),
    },
    "FewRel": {
        "model_false": np.array([1656, 1857, 1949, 1271, 1615]),
        "correct_judged": np.array([1282, 1483, 1641, 976, 1260]),
    }
}

# -----------------------
# Output directory
# -----------------------
out_dir = "judge_bar_plots_clean"
os.makedirs(out_dir, exist_ok=True)

def fmt_int(n):
    return f"{int(n):,}"

# -----------------------
# Plot
# -----------------------
for dataset, d in data.items():

    fig, ax = plt.subplots(figsize=(12, 5.2))

    bars1 = ax.bar(
        x - bar_w / 2,
        d["model_false"],
        width=bar_w,
        label="Model False Prediction",
        color="#1f77b4",
        edgecolor="black",
        linewidth=0.4
    )

    bars2 = ax.bar(
        x + bar_w / 2,
        d["correct_judged"],
        width=bar_w,
        label="Correctly Judged False",
        color="#ff7f0e",
        edgecolor="black",
        linewidth=0.4
    )

    # Subtle horizontal grid
    ax.grid(axis="y", linestyle="-", linewidth=0.5, alpha=0.25)
    ax.set_axisbelow(True)

    ax.set_title(dataset, weight="bold", fontsize=14)
    ax.set_xlabel("Run", fontsize=12, weight="bold")
    ax.set_ylabel("Count", fontsize=12, weight="bold")
    ax.set_xticks(x)
    ax.set_xticklabels(runs, fontsize=12, weight="bold")

    # Add headroom
    ymax = float(max(d["model_false"].max(), d["correct_judged"].max()))
    ax.set_ylim(0, ymax * 1.15)

    # -----------------------
    # Value labels (counts only)
    # -----------------------
    y_offset = ymax * 0.015

    for bars in [bars1, bars2]:
        for bar in bars:
            h = bar.get_height()
            ax.text(
                bar.get_x() + bar.get_width() / 2,
                h + y_offset,
                fmt_int(h),
                ha="center",
                va="bottom",
                fontsize=14
            )

    # Legend outside
    ax.legend(
        frameon=False,
        loc="lower center",
        bbox_to_anchor=(0.5, 1.06),
        ncol=2,
        fontsize=14
        
    )

    fig.tight_layout(rect=[0, 0, 0.80, 1])
    plt.savefig(f"{out_dir}/{dataset.lower()}_judge_grouped_clean.pdf", dpi=300)
    plt.show()

# %%
### ----------------------- LLM as a Judge with NLI

import numpy as np
import matplotlib.pyplot as plt
from matplotlib import rcParams
import os

# -----------------------
# Style (paper-friendly, big figure)
# -----------------------
rcParams.update({
    "font.family": "serif",
    "font.size": 14,
    "axes.titlesize": 16,
    "axes.labelsize": 14,
    "xtick.labelsize": 14,
    "ytick.labelsize": 14,
    "axes.linewidth": 0.8,
})

# -----------------------
# Data
# -----------------------
runs = np.arange(1, 6)
x = np.arange(len(runs))
bar_w = 0.48

data = {
    "TACRED": {
        "model_false": np.array([159, 349, 253, 421, 217]),
        "correct_judged": np.array([151, 336, 234, 376, 196]),
    },
    "FewRel": {
        "model_false": np.array([1656, 1857, 1949, 1271, 1615]),
        "correct_judged": np.array([1370, 1580, 1722, 1045, 1336]),
    }
}

# -----------------------
# Output directory
# -----------------------
out_dir = "judge_bar_nli"
os.makedirs(out_dir, exist_ok=True)

def fmt_int(n):
    return f"{int(n):,}"

# -----------------------
# Plot
# -----------------------
for dataset, d in data.items():

    fig, ax = plt.subplots(figsize=(12, 5.2))

    bars1 = ax.bar(
        x - bar_w / 2,
        d["model_false"],
        width=bar_w,
        label="Model False Prediction",
        color="#1f77b4",
        edgecolor="black",
        linewidth=0.4
    )

    bars2 = ax.bar(
        x + bar_w / 2,
        d["correct_judged"],
        width=bar_w,
        label="Correctly Judged False",
        color="#ff7f0e",
        edgecolor="black",
        linewidth=0.4
    )

    # Subtle horizontal grid
    ax.grid(axis="y", linestyle="-", linewidth=0.5, alpha=0.25)
    ax.set_axisbelow(True)
    title = f"{dataset}: Textual Entailment Format"
    ax.set_title(title, fontsize=14, weight="bold")
    ax.set_xlabel("Run", fontsize=12, weight="bold")
    ax.set_ylabel("Count", fontsize=12, weight="bold")
    ax.set_xticks(x)
    ax.set_xticklabels(runs)

    # Add headroom
    ymax = float(max(d["model_false"].max(), d["correct_judged"].max()))
    ax.set_ylim(0, ymax * 1.15)

    # -----------------------
    # Value labels (counts only)
    # -----------------------
    y_offset = ymax * 0.015

    for bars in [bars1, bars2]:
        for bar in bars:
            h = bar.get_height()
            ax.text(
                bar.get_x() + bar.get_width() / 2,
                h + y_offset,
                fmt_int(h),
                ha="center",
                va="bottom",
                fontsize=14
            )

    # Legend outside
    ax.legend(
        frameon=False,
        loc="lower center",
        bbox_to_anchor=(0.5, 1.06),
        ncol=2,
        fontsize=14
    )
    fig.tight_layout(rect=[0, 0, 0.80, 1])
    plt.savefig(f"{out_dir}/{dataset.lower()}_judge_nli_gemini.pdf", dpi=300)
    plt.show()
