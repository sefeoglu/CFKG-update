# %%
import os
import json
from sklearn.metrics import multilabel_confusion_matrix, accuracy_score
import numpy as np
import pandas as pd

def read_json(path):
    with open(path, 'r', encoding="utf-8") as f:
        data = json.load(f)
    return data

def write_json(data, path):
    if not os.path.exists(os.path.dirname(path)):
        os.makedirs(os.path.dirname(path))
    with open(path, 'w', encoding="utf-8") as f:
        json.dump(data, f, indent=4, ensure_ascii=False)

# %%
import numpy as np

def compute_forgetting_matrix(accuracy_matrix):
    """
    Computes forgetting for each task.
    
    Parameters:
    - accuracy_matrix: 2D numpy array of shape (num_tasks, num_tasks)
      Each row i represents accuracy on task i after training on tasks j=0..T-1
    
    Returns:
    - forgetting: list of forgetting values for each task
    - avg_forgetting: average forgetting across tasks (excluding the last task)
    """
    num_tasks = accuracy_matrix.shape[0]
    forgetting = []

    for i in range(num_tasks - 1):
        max_acc = np.max(accuracy_matrix[i, :i+1])  # Max accuracy before final training
        final_acc = accuracy_matrix[i, -1]          # Accuracy after training on all tasks
        forgetting.append(max_acc - final_acc)

    avg_forgetting = np.mean(forgetting)
    return forgetting, avg_forgetting

# %%
# Rows: tasks, Columns: performance after training on each task
accuracy_matrix = np.array([
    [0.9, 0.85, 0.70],  # Task 1
    [0.0, 0.88, 0.75],  # Task 2
    [0.0, 0.0, 0.92],   # Task 3
])

forgetting, avg_forgetting = compute_forgetting_matrix(accuracy_matrix)

print("Forgetting per task:", forgetting)
print("Average Forgetting:", avg_forgetting)
# Out:
# Forgetting per task: [0.20000000000000007, 0.13]
# Average Forgetting: 0.16500000000000004

# %%
# matrices preparation on T5
def compute_forgetting_matrix_t5(input_folder, test_folder):
    results = []
    for i in range(1, 9):
       input_file = f"/Users/sefika/phd_projects/llm-catastrophic-re/last_results/tacred/tacred_oja/{input_folder}/test_pred_{i}.json"
       start=0 
       predictions = read_json(input_file)
       predictions = [item['predict'] for item in predictions]
       
       for id in range(1, i+1):
        test_file = f"/Users/sefika/phd_projects/draft/FS-CRE/data/data/tacred/5way5shot_same_setting_kmeans/5way5shot-test/{test_folder}/task{id}/test.json"
        test_data = read_json(test_file)
        y_true = [item['relation'] for item in test_data]
        y_task = predictions[start:start+len(y_true)]
        acc = accuracy_score(y_true, y_task)
        print(f"Task {i} - Task {id} Accuracy: {acc:.4f}")
        print(f"Task {i} - Task {id} Size: {len(y_task)}")
        print(f"Task {i} - Task {id} True Size: {len(y_true)}")

        row = {'base_task':i , 'task':id, 'accuracy':acc}
        
        start += len(y_true)
        results.append(row)
    return results
for run_id in range(1, 6):
    results = compute_forgetting_matrix_t5(
        input_folder=f"model_{run_id}",
        test_folder=f"run{run_id}"
    )
    results
    write_json(results, f"/Users/sefika/phd_projects/llm-catastrophic-re/last_results/tacred/tacred_oja/model_{run_id}_forgetting_matrix.json")
# Out:
# Task 1 - Task 1 Accuracy: 0.9818
# Task 1 - Task 1 Size: 770
# Task 1 - Task 1 True Size: 770
# Task 2 - Task 1 Accuracy: 0.9714
# Task 2 - Task 1 Size: 770
# Task 2 - Task 1 True Size: 770
# Task 2 - Task 2 Accuracy: 0.9882
# Task 2 - Task 2 Size: 591
# Task 2 - Task 2 True Size: 591
# Task 3 - Task 1 Accuracy: 0.9766
# Task 3 - Task 1 Size: 770
# Task 3 - Task 1 True Size: 770
# Task 3 - Task 2 Accuracy: 0.9865
# Task 3 - Task 2 Size: 591
# Task 3 - Task 2 True Size: 591
# Task 3 - Task 3 Accuracy: 0.9972
# Task 3 - Task 3 Size: 356
# Task 3 - Task 3 True Size: 356
# Task 4 - Task 1 Accuracy: 0.9714
# Task 4 - Task 1 Size: 770
# Task 4 - Task 1 True Size: 770
# Task 4 - Task 2 Accuracy: 0.9848
# Task 4 - Task 2 Size: 591
# Task 4 - Task 2 True Size: 591
# Task 4 - Task 3 Accuracy: 0.9944
# Task 4 - Task 3 Size: 356
# Task 4 - Task 3 True Size: 356
# Task 4 - Task 4 Accuracy: 0.9729
# Task 4 - Task 4 Size: 295
# Task 4 - Task 4 True Size: 295
# Task 5 - Task 1 Accuracy: 0.9675
# Task 5 - Task 1 Size: 770
# Task 5 - Task 1 True Size: 770
# Task 5 - Task 2 Accuracy: 0.9831
# Task 5 - Task 2 Size: 591
# Task 5 - Task 2 True Size: 591
# Task 5 - Task 3 Accuracy: 0.9972
# Task 5 - Task 3 Size: 356
# Task 5 - Task 3 True Size: 356
# Task 5 - Task 4 Accuracy: 0.9627
# Task 5 - Task 4 Size: 295
# Task 5 - Task 4 True Size: 295
# Task 5 - Task 5 Accuracy: 0.9401
# Task 5 - Task 5 Size: 451
# Task 5 - Task 5 True Size: 451
# Task 6 - Task 1 Accuracy: 0.9623
# Task 6 - Task 1 Size: 770
# Task 6 - Task 1 True Size: 770
# Task 6 - Task 2 Accuracy: 0.9763
# Task 6 - Task 2 Size: 591
# Task 6 - Task 2 True Size: 591
# Task 6 - Task 3 Accuracy: 0.9972
# Task 6 - Task 3 Size: 356
# Task 6 - Task 3 True Size: 356
# Task 6 - Task 4 Accuracy: 0.9322
# Task 6 - Task 4 Size: 295
# Task 6 - Task 4 True Size: 295
# Task 6 - Task 5 Accuracy: 0.9357
# Task 6 - Task 5 Size: 451
# Task 6 - Task 5 True Size: 451
# Task 6 - Task 6 Accuracy: 0.8985
# Task 6 - Task 6 Size: 532
# Task 6 - Task 6 True Size: 532
# Task 7 - Task 1 Accuracy: 0.9623
# Task 7 - Task 1 Size: 770
# Task 7 - Task 1 True Size: 770
# Task 7 - Task 2 Accuracy: 0.9628
# Task 7 - Task 2 Size: 591
# Task 7 - Task 2 True Size: 591
# Task 7 - Task 3 Accuracy: 0.9972
# Task 7 - Task 3 Size: 356
# Task 7 - Task 3 True Size: 356
# Task 7 - Task 4 Accuracy: 0.9220
# Task 7 - Task 4 Size: 295
# Task 7 - Task 4 True Size: 295
# Task 7 - Task 5 Accuracy: 0.9379
# Task 7 - Task 5 Size: 451
# Task 7 - Task 5 True Size: 451
# Task 7 - Task 6 Accuracy: 0.8835
# Task 7 - Task 6 Size: 532
# Task 7 - Task 6 True Size: 532
# Task 7 - Task 7 Accuracy: 0.9683
# Task 7 - Task 7 Size: 221
# Task 7 - Task 7 True Size: 221
# Task 8 - Task 1 Accuracy: 0.9649
# Task 8 - Task 1 Size: 770
# Task 8 - Task 1 True Size: 770
# Task 8 - Task 2 Accuracy: 0.9628
# Task 8 - Task 2 Size: 591
# Task 8 - Task 2 True Size: 591
# Task 8 - Task 3 Accuracy: 0.9972
# Task 8 - Task 3 Size: 356
# Task 8 - Task 3 True Size: 356
# Task 8 - Task 4 Accuracy: 0.9356
# Task 8 - Task 4 Size: 295
# Task 8 - Task 4 True Size: 295
# Task 8 - Task 5 Accuracy: 0.9601
# Task 8 - Task 5 Size: 451
# Task 8 - Task 5 True Size: 451
# Task 8 - Task 6 Accuracy: 0.8891
# Task 8 - Task 6 Size: 532
# Task 8 - Task 6 True Size: 532
# Task 8 - Task 7 Accuracy: 0.9638
# Task 8 - Task 7 Size: 221
# Task 8 - Task 7 True Size: 221
# Task 8 - Task 8 Accuracy: 0.8624
# Task 8 - Task 8 Size: 109
# Task 8 - Task 8 True Size: 109
# Task 1 - Task 1 Accuracy: 0.9912
# Task 1 - Task 1 Size: 456
# Task 1 - Task 1 True Size: 456
# Task 2 - Task 1 Accuracy: 0.9868
# Task 2 - Task 1 Size: 456
# Task 2 - Task 1 True Size: 456
# Task 2 - Task 2 Accuracy: 0.8479
# Task 2 - Task 2 Size: 309
# Task 2 - Task 2 True Size: 309
# Task 3 - Task 1 Accuracy: 0.9759
# Task 3 - Task 1 Size: 456
# Task 3 - Task 1 True Size: 456
# Task 3 - Task 2 Accuracy: 0.6278
# Task 3 - Task 2 Size: 309
# Task 3 - Task 2 True Size: 309
# Task 3 - Task 3 Accuracy: 0.9213
# Task 3 - Task 3 Size: 356
# Task 3 - Task 3 True Size: 356
# Task 4 - Task 1 Accuracy: 0.9693
# Task 4 - Task 1 Size: 456
# Task 4 - Task 1 True Size: 456
# Task 4 - Task 2 Accuracy: 0.6667
# Task 4 - Task 2 Size: 309
# Task 4 - Task 2 True Size: 309
# Task 4 - Task 3 Accuracy: 0.8764
# Task 4 - Task 3 Size: 356
# Task 4 - Task 3 True Size: 356
# Task 4 - Task 4 Accuracy: 0.9857
# Task 4 - Task 4 Size: 630
# Task 4 - Task 4 True Size: 630
# Task 5 - Task 1 Accuracy: 0.9649
# Task 5 - Task 1 Size: 456
# Task 5 - Task 1 True Size: 456
# Task 5 - Task 2 Accuracy: 0.7217
# Task 5 - Task 2 Size: 309
# Task 5 - Task 2 True Size: 309
# Task 5 - Task 3 Accuracy: 0.9129
# Task 5 - Task 3 Size: 356
# Task 5 - Task 3 True Size: 356
# Task 5 - Task 4 Accuracy: 0.9810
# Task 5 - Task 4 Size: 630
# Task 5 - Task 4 True Size: 630
# Task 5 - Task 5 Accuracy: 0.8788
# Task 5 - Task 5 Size: 495
# Task 5 - Task 5 True Size: 495
# Task 6 - Task 1 Accuracy: 0.9737
# Task 6 - Task 1 Size: 456
# Task 6 - Task 1 True Size: 456
# Task 6 - Task 2 Accuracy: 0.6893
# Task 6 - Task 2 Size: 309
# Task 6 - Task 2 True Size: 309
# Task 6 - Task 3 Accuracy: 0.9129
# Task 6 - Task 3 Size: 356
# Task 6 - Task 3 True Size: 356
# Task 6 - Task 4 Accuracy: 0.9873
# Task 6 - Task 4 Size: 630
# Task 6 - Task 4 True Size: 630
# Task 6 - Task 5 Accuracy: 0.8000
# Task 6 - Task 5 Size: 495
# Task 6 - Task 5 True Size: 495
# Task 6 - Task 6 Accuracy: 0.9000
# Task 6 - Task 6 Size: 130
# Task 6 - Task 6 True Size: 130
# Task 7 - Task 1 Accuracy: 0.9737
# Task 7 - Task 1 Size: 456
# Task 7 - Task 1 True Size: 456
# Task 7 - Task 2 Accuracy: 0.7152
# Task 7 - Task 2 Size: 309
# Task 7 - Task 2 True Size: 309
# Task 7 - Task 3 Accuracy: 0.9213
# Task 7 - Task 3 Size: 356
# Task 7 - Task 3 True Size: 356
# Task 7 - Task 4 Accuracy: 0.9841
# Task 7 - Task 4 Size: 630
# Task 7 - Task 4 True Size: 630
# Task 7 - Task 5 Accuracy: 0.7636
# Task 7 - Task 5 Size: 495
# Task 7 - Task 5 True Size: 495
# Task 7 - Task 6 Accuracy: 0.9000
# Task 7 - Task 6 Size: 130
# Task 7 - Task 6 True Size: 130
# Task 7 - Task 7 Accuracy: 0.8120
# Task 7 - Task 7 Size: 266
# Task 7 - Task 7 True Size: 266
# Task 8 - Task 1 Accuracy: 0.9846
# Task 8 - Task 1 Size: 456
# Task 8 - Task 1 True Size: 456
# Task 8 - Task 2 Accuracy: 0.7023
# Task 8 - Task 2 Size: 309
# Task 8 - Task 2 True Size: 309
# Task 8 - Task 3 Accuracy: 0.8652
# Task 8 - Task 3 Size: 356
# Task 8 - Task 3 True Size: 356
# Task 8 - Task 4 Accuracy: 0.9841
# Task 8 - Task 4 Size: 630
# Task 8 - Task 4 True Size: 630
# Task 8 - Task 5 Accuracy: 0.8222
# Task 8 - Task 5 Size: 495
# Task 8 - Task 5 True Size: 495
# Task 8 - Task 6 Accuracy: 0.9000
# Task 8 - Task 6 Size: 130
# Task 8 - Task 6 True Size: 130
# Task 8 - Task 7 Accuracy: 0.7932
# Task 8 - Task 7 Size: 266
# Task 8 - Task 7 True Size: 266
# Task 8 - Task 8 Accuracy: 0.9400
# Task 8 - Task 8 Size: 683
# Task 8 - Task 8 True Size: 683
# Task 1 - Task 1 Accuracy: 0.9684
# Task 1 - Task 1 Size: 190
# Task 1 - Task 1 True Size: 190
# Task 2 - Task 1 Accuracy: 0.9579
# Task 2 - Task 1 Size: 190
# Task 2 - Task 1 True Size: 190
# Task 2 - Task 2 Accuracy: 0.8960
# Task 2 - Task 2 Size: 529
# Task 2 - Task 2 True Size: 529
# Task 3 - Task 1 Accuracy: 0.9632
# Task 3 - Task 1 Size: 190
# Task 3 - Task 1 True Size: 190
# Task 3 - Task 2 Accuracy: 0.8639
# Task 3 - Task 2 Size: 529
# Task 3 - Task 2 True Size: 529
# Task 3 - Task 3 Accuracy: 0.9481
# Task 3 - Task 3 Size: 443
# Task 3 - Task 3 True Size: 443
# Task 4 - Task 1 Accuracy: 0.9684
# Task 4 - Task 1 Size: 190
# Task 4 - Task 1 True Size: 190
# Task 4 - Task 2 Accuracy: 0.8866
# Task 4 - Task 2 Size: 529
# Task 4 - Task 2 True Size: 529
# Task 4 - Task 3 Accuracy: 0.9097
# Task 4 - Task 3 Size: 443
# Task 4 - Task 3 True Size: 443
# Task 4 - Task 4 Accuracy: 0.9812
# Task 4 - Task 4 Size: 586
# Task 4 - Task 4 True Size: 586
# Task 5 - Task 1 Accuracy: 0.9632
# Task 5 - Task 1 Size: 190
# Task 5 - Task 1 True Size: 190
# Task 5 - Task 2 Accuracy: 0.9301
# Task 5 - Task 2 Size: 529
# Task 5 - Task 2 True Size: 529
# Task 5 - Task 3 Accuracy: 0.9097
# Task 5 - Task 3 Size: 443
# Task 5 - Task 3 True Size: 443
# Task 5 - Task 4 Accuracy: 0.9693
# Task 5 - Task 4 Size: 586
# Task 5 - Task 4 True Size: 586
# Task 5 - Task 5 Accuracy: 0.9516
# Task 5 - Task 5 Size: 372
# Task 5 - Task 5 True Size: 372
# Task 6 - Task 1 Accuracy: 0.9579
# Task 6 - Task 1 Size: 190
# Task 6 - Task 1 True Size: 190
# Task 6 - Task 2 Accuracy: 0.7316
# Task 6 - Task 2 Size: 529
# Task 6 - Task 2 True Size: 529
# Task 6 - Task 3 Accuracy: 0.9255
# Task 6 - Task 3 Size: 443
# Task 6 - Task 3 True Size: 443
# Task 6 - Task 4 Accuracy: 0.9676
# Task 6 - Task 4 Size: 586
# Task 6 - Task 4 True Size: 586
# Task 6 - Task 5 Accuracy: 0.9247
# Task 6 - Task 5 Size: 372
# Task 6 - Task 5 True Size: 372
# Task 6 - Task 6 Accuracy: 0.8244
# Task 6 - Task 6 Size: 279
# Task 6 - Task 6 True Size: 279
# Task 7 - Task 1 Accuracy: 0.9684
# Task 7 - Task 1 Size: 190
# Task 7 - Task 1 True Size: 190
# Task 7 - Task 2 Accuracy: 0.6238
# Task 7 - Task 2 Size: 529
# Task 7 - Task 2 True Size: 529
# Task 7 - Task 3 Accuracy: 0.8804
# Task 7 - Task 3 Size: 443
# Task 7 - Task 3 True Size: 443
# Task 7 - Task 4 Accuracy: 0.9556
# Task 7 - Task 4 Size: 586
# Task 7 - Task 4 True Size: 586
# Task 7 - Task 5 Accuracy: 0.9059
# Task 7 - Task 5 Size: 372
# Task 7 - Task 5 True Size: 372
# Task 7 - Task 6 Accuracy: 0.8387
# Task 7 - Task 6 Size: 279
# Task 7 - Task 6 True Size: 279
# Task 7 - Task 7 Accuracy: 0.9809
# Task 7 - Task 7 Size: 734
# Task 7 - Task 7 True Size: 734
# Task 8 - Task 1 Accuracy: 0.9684
# Task 8 - Task 1 Size: 190
# Task 8 - Task 1 True Size: 190
# Task 8 - Task 2 Accuracy: 0.8847
# Task 8 - Task 2 Size: 529
# Task 8 - Task 2 True Size: 529
# Task 8 - Task 3 Accuracy: 0.8871
# Task 8 - Task 3 Size: 443
# Task 8 - Task 3 True Size: 443
# Task 8 - Task 4 Accuracy: 0.9317
# Task 8 - Task 4 Size: 586
# Task 8 - Task 4 True Size: 586
# Task 8 - Task 5 Accuracy: 0.9086
# Task 8 - Task 5 Size: 372
# Task 8 - Task 5 True Size: 372
# Task 8 - Task 6 Accuracy: 0.8423
# Task 8 - Task 6 Size: 279
# Task 8 - Task 6 True Size: 279
# Task 8 - Task 7 Accuracy: 0.9796
# Task 8 - Task 7 Size: 734
# Task 8 - Task 7 True Size: 734
# Task 8 - Task 8 Accuracy: 0.9844
# Task 8 - Task 8 Size: 192
# Task 8 - Task 8 True Size: 192
# Task 1 - Task 1 Accuracy: 0.9897
# Task 1 - Task 1 Size: 1160
# Task 1 - Task 1 True Size: 1160
# Task 2 - Task 1 Accuracy: 0.9853
# Task 2 - Task 1 Size: 1160
# Task 2 - Task 1 True Size: 1160
# Task 2 - Task 2 Accuracy: 0.9261
# Task 2 - Task 2 Size: 176
# Task 2 - Task 2 True Size: 176
# Task 3 - Task 1 Accuracy: 0.9836
# Task 3 - Task 1 Size: 1160
# Task 3 - Task 1 True Size: 1160
# Task 3 - Task 2 Accuracy: 0.9261
# Task 3 - Task 2 Size: 176
# Task 3 - Task 2 True Size: 176
# Task 3 - Task 3 Accuracy: 0.8892
# Task 3 - Task 3 Size: 370
# Task 3 - Task 3 True Size: 370
# Task 4 - Task 1 Accuracy: 0.9862
# Task 4 - Task 1 Size: 1160
# Task 4 - Task 1 True Size: 1160
# Task 4 - Task 2 Accuracy: 0.8920
# Task 4 - Task 2 Size: 176
# Task 4 - Task 2 True Size: 176
# Task 4 - Task 3 Accuracy: 0.8865
# Task 4 - Task 3 Size: 370
# Task 4 - Task 3 True Size: 370
# Task 4 - Task 4 Accuracy: 0.7857
# Task 4 - Task 4 Size: 504
# Task 4 - Task 4 True Size: 504
# Task 5 - Task 1 Accuracy: 0.9836
# Task 5 - Task 1 Size: 1160
# Task 5 - Task 1 True Size: 1160
# Task 5 - Task 2 Accuracy: 0.9034
# Task 5 - Task 2 Size: 176
# Task 5 - Task 2 True Size: 176
# Task 5 - Task 3 Accuracy: 0.7459
# Task 5 - Task 3 Size: 370
# Task 5 - Task 3 True Size: 370
# Task 5 - Task 4 Accuracy: 0.7917
# Task 5 - Task 4 Size: 504
# Task 5 - Task 4 True Size: 504
# Task 5 - Task 5 Accuracy: 0.9066
# Task 5 - Task 5 Size: 503
# Task 5 - Task 5 True Size: 503
# Task 6 - Task 1 Accuracy: 0.9810
# Task 6 - Task 1 Size: 1160
# Task 6 - Task 1 True Size: 1160
# Task 6 - Task 2 Accuracy: 0.8693
# Task 6 - Task 2 Size: 176
# Task 6 - Task 2 True Size: 176
# Task 6 - Task 3 Accuracy: 0.6838
# Task 6 - Task 3 Size: 370
# Task 6 - Task 3 True Size: 370
# Task 6 - Task 4 Accuracy: 0.7698
# Task 6 - Task 4 Size: 504
# Task 6 - Task 4 True Size: 504
# Task 6 - Task 5 Accuracy: 0.9205
# Task 6 - Task 5 Size: 503
# Task 6 - Task 5 True Size: 503
# Task 6 - Task 6 Accuracy: 0.9563
# Task 6 - Task 6 Size: 229
# Task 6 - Task 6 True Size: 229
# Task 7 - Task 1 Accuracy: 0.9810
# Task 7 - Task 1 Size: 1160
# Task 7 - Task 1 True Size: 1160
# Task 7 - Task 2 Accuracy: 0.8693
# Task 7 - Task 2 Size: 176
# Task 7 - Task 2 True Size: 176
# Task 7 - Task 3 Accuracy: 0.6676
# Task 7 - Task 3 Size: 370
# Task 7 - Task 3 True Size: 370
# Task 7 - Task 4 Accuracy: 0.7024
# Task 7 - Task 4 Size: 504
# Task 7 - Task 4 True Size: 504
# Task 7 - Task 5 Accuracy: 0.9324
# Task 7 - Task 5 Size: 503
# Task 7 - Task 5 True Size: 503
# Task 7 - Task 6 Accuracy: 0.9651
# Task 7 - Task 6 Size: 229
# Task 7 - Task 6 True Size: 229
# Task 7 - Task 7 Accuracy: 0.9384
# Task 7 - Task 7 Size: 276
# Task 7 - Task 7 True Size: 276
# Task 8 - Task 1 Accuracy: 0.9793
# Task 8 - Task 1 Size: 1160
# Task 8 - Task 1 True Size: 1160
# Task 8 - Task 2 Accuracy: 0.9205
# Task 8 - Task 2 Size: 176
# Task 8 - Task 2 True Size: 176
# Task 8 - Task 3 Accuracy: 0.7432
# Task 8 - Task 3 Size: 370
# Task 8 - Task 3 True Size: 370
# Task 8 - Task 4 Accuracy: 0.5952
# Task 8 - Task 4 Size: 504
# Task 8 - Task 4 True Size: 504
# Task 8 - Task 5 Accuracy: 0.9046
# Task 8 - Task 5 Size: 503
# Task 8 - Task 5 True Size: 503
# Task 8 - Task 6 Accuracy: 0.9651
# Task 8 - Task 6 Size: 229
# Task 8 - Task 6 True Size: 229
# Task 8 - Task 7 Accuracy: 0.9203
# Task 8 - Task 7 Size: 276
# Task 8 - Task 7 True Size: 276
# Task 8 - Task 8 Accuracy: 0.9626
# Task 8 - Task 8 Size: 107
# Task 8 - Task 8 True Size: 107
# Task 1 - Task 1 Accuracy: 0.9034
# Task 1 - Task 1 Size: 290
# Task 1 - Task 1 True Size: 290
# Task 2 - Task 1 Accuracy: 0.9138
# Task 2 - Task 1 Size: 290
# Task 2 - Task 1 True Size: 290
# Task 2 - Task 2 Accuracy: 0.9944
# Task 2 - Task 2 Size: 719
# Task 2 - Task 2 True Size: 719
# Task 3 - Task 1 Accuracy: 0.9207
# Task 3 - Task 1 Size: 290
# Task 3 - Task 1 True Size: 290
# Task 3 - Task 2 Accuracy: 0.9917
# Task 3 - Task 2 Size: 719
# Task 3 - Task 2 True Size: 719
# Task 3 - Task 3 Accuracy: 0.9427
# Task 3 - Task 3 Size: 436
# Task 3 - Task 3 True Size: 436
# Task 4 - Task 1 Accuracy: 0.8931
# Task 4 - Task 1 Size: 290
# Task 4 - Task 1 True Size: 290
# Task 4 - Task 2 Accuracy: 0.9972
# Task 4 - Task 2 Size: 719
# Task 4 - Task 2 True Size: 719
# Task 4 - Task 3 Accuracy: 0.7385
# Task 4 - Task 3 Size: 436
# Task 4 - Task 3 True Size: 436
# Task 4 - Task 4 Accuracy: 0.9811
# Task 4 - Task 4 Size: 159
# Task 4 - Task 4 True Size: 159
# Task 5 - Task 1 Accuracy: 0.9138
# Task 5 - Task 1 Size: 290
# Task 5 - Task 1 True Size: 290
# Task 5 - Task 2 Accuracy: 0.9930
# Task 5 - Task 2 Size: 719
# Task 5 - Task 2 True Size: 719
# Task 5 - Task 3 Accuracy: 0.7523
# Task 5 - Task 3 Size: 436
# Task 5 - Task 3 True Size: 436
# Task 5 - Task 4 Accuracy: 0.9811
# Task 5 - Task 4 Size: 159
# Task 5 - Task 4 True Size: 159
# Task 5 - Task 5 Accuracy: 0.9655
# Task 5 - Task 5 Size: 174
# Task 5 - Task 5 True Size: 174
# Task 6 - Task 1 Accuracy: 0.8793
# Task 6 - Task 1 Size: 290
# Task 6 - Task 1 True Size: 290
# Task 6 - Task 2 Accuracy: 0.9889
# Task 6 - Task 2 Size: 719
# Task 6 - Task 2 True Size: 719
# Task 6 - Task 3 Accuracy: 0.9128
# Task 6 - Task 3 Size: 436
# Task 6 - Task 3 True Size: 436
# Task 6 - Task 4 Accuracy: 0.9937
# Task 6 - Task 4 Size: 159
# Task 6 - Task 4 True Size: 159
# Task 6 - Task 5 Accuracy: 0.9253
# Task 6 - Task 5 Size: 174
# Task 6 - Task 5 True Size: 174
# Task 6 - Task 6 Accuracy: 0.8744
# Task 6 - Task 6 Size: 804
# Task 6 - Task 6 True Size: 804
# Task 7 - Task 1 Accuracy: 0.8517
# Task 7 - Task 1 Size: 290
# Task 7 - Task 1 True Size: 290
# Task 7 - Task 2 Accuracy: 0.9875
# Task 7 - Task 2 Size: 719
# Task 7 - Task 2 True Size: 719
# Task 7 - Task 3 Accuracy: 0.9151
# Task 7 - Task 3 Size: 436
# Task 7 - Task 3 True Size: 436
# Task 7 - Task 4 Accuracy: 0.9874
# Task 7 - Task 4 Size: 159
# Task 7 - Task 4 True Size: 159
# Task 7 - Task 5 Accuracy: 0.8678
# Task 7 - Task 5 Size: 174
# Task 7 - Task 5 True Size: 174
# Task 7 - Task 6 Accuracy: 0.9067
# Task 7 - Task 6 Size: 804
# Task 7 - Task 6 True Size: 804
# Task 7 - Task 7 Accuracy: 0.9412
# Task 7 - Task 7 Size: 340
# Task 7 - Task 7 True Size: 340
# Task 8 - Task 1 Accuracy: 0.8724
# Task 8 - Task 1 Size: 290
# Task 8 - Task 1 True Size: 290
# Task 8 - Task 2 Accuracy: 0.9861
# Task 8 - Task 2 Size: 719
# Task 8 - Task 2 True Size: 719
# Task 8 - Task 3 Accuracy: 0.9404
# Task 8 - Task 3 Size: 436
# Task 8 - Task 3 True Size: 436
# Task 8 - Task 4 Accuracy: 0.9811
# Task 8 - Task 4 Size: 159
# Task 8 - Task 4 True Size: 159
# Task 8 - Task 5 Accuracy: 0.8506
# Task 8 - Task 5 Size: 174
# Task 8 - Task 5 True Size: 174
# Task 8 - Task 6 Accuracy: 0.8980
# Task 8 - Task 6 Size: 804
# Task 8 - Task 6 True Size: 804
# Task 8 - Task 7 Accuracy: 0.9382
# Task 8 - Task 7 Size: 340
# Task 8 - Task 7 True Size: 340
# Task 8 - Task 8 Accuracy: 0.9677
# Task 8 - Task 8 Size: 403
# Task 8 - Task 8 True Size: 403

# %%
# matrices preparation on Mistral

# %%
# matrices preparation on Llama-2
